# %% [markdown]
# ---
# <img src="https://asset.brandfetch.io/idvDrMBg3m/idgDR62lX4.png" alt="Logo Data Rockstars" width="274" height="80">
#
# ### 🔒 Le contenu de ce document est confidentiel. 📝
# _Le contenu de ce document est confidentiel et la copie ou la distribution est interdite._ 😶‍🌫️
#
# 📧 Pour toute question, veuillez nous contacter à [contact@datarockstars.ai](mailto:contact@datarockstars.ai)
#
# ---
# # Le programme du notebook
#
# **📖 Au programme**
# - Cours guidé pour apprendre en s'exerçant
# - Exercices avec différents niveaux
# - Exercices avancés : pour aller plus loin
#
# **🎁 Les takeaways**
# - Accès à la plateforme
# - Notebooks
# - Snippets penses bêtes de code que vous pouvez garder à vie
#
# ---
#
# 🔰 Démarrez en exécutant chaque segment de code un à un et en analysant les résultats affichés.
#
# ---
# A vous de jouer 😎✌️

# %% [markdown]
# ## 1. Les librairies à importer

# %%
import pandas as pd

import matplotlib.pyplot as plt

# %% [markdown]
# ## 2. Cours

# %%
# Step 1 : Spécifier le chemin vers le fichier CSV que l'on souhaite télécharger. 
csv_file = "data/rockstars.csv"

# Step 2 : Lire votre dataframe en utilisant la fonction read_csv
df = pd.read_csv(csv_file)

# %%
# Afficher le DataFrame
df
# Out:
#           Guitariste                                            Guitare  \
# 0    Freddie Mercury                         Guitar Fender Stratocaster
# 1       Jimi Hendrix                          Amplifier Marshall JCM800
# 2         Jimmy Page                         Drums Ludwig Classic Maple
# 3        David Bowie  Vinyl Record Pink Floyd - The Dark Side of the...
# 4       Stevie Nicks                               Keyboard Yamaha CP88
# 5  Bruce Springsteen                     Electric Bass Fender Precision
# 6         Elton John                              Microphone Shure SM58
# 7       Janis Joplin                        Acoustic Guitar Martin D-28
# 8        John Lennon                  Synthesizer Moog Minimoog Model D
# 9        Kurt Cobain                    Electric Guitar Gibson Les Paul
#
#    Prix moyen neuf      Ville        Date
# 0           1500.0      Paris  2023-01-05
# 1           3200.0  Marseille  2023-01-12
# 2           4000.0       Lyon  2023-01-20
# ...

# %%
# Afficher les premières lignes
df.head()
# Out:
#         Guitariste                                            Guitare  \
# 0  Freddie Mercury                         Guitar Fender Stratocaster
# 1     Jimi Hendrix                          Amplifier Marshall JCM800
# 2       Jimmy Page                         Drums Ludwig Classic Maple
# 3      David Bowie  Vinyl Record Pink Floyd - The Dark Side of the...
# 4     Stevie Nicks                               Keyboard Yamaha CP88
#
#    Prix moyen neuf      Ville        Date
# 0           1500.0      Paris  2023-01-05
# 1           3200.0  Marseille  2023-01-12
# 2           4000.0       Lyon  2023-01-20
# 3           3100.0      Paris  2023-02-02
# 4           1800.0       Nice  2023-02-15

# %%
# Afficher les dernières lignes
df.tail()
# Out:
#           Guitariste                            Guitare  Prix moyen neuf  \
# 5  Bruce Springsteen     Electric Bass Fender Precision           1000.0
# 6         Elton John              Microphone Shure SM58            150.0
# 7       Janis Joplin        Acoustic Guitar Martin D-28           2500.0
# 8        John Lennon  Synthesizer Moog Minimoog Model D           3000.0
# 9        Kurt Cobain    Electric Guitar Gibson Les Paul           2000.0
#
#        Ville        Date
# 5   Bordeaux  2023-02-28
# 6   Toulouse  2023-03-10
# 7      Paris  2023-03-22
# 8       Lyon  2023-04-05
# 9  Marseille  2023-04-18

# %%
# Sélection d'une colonne
df['Guitare']
# Out:
# 0                           Guitar Fender Stratocaster
# 1                            Amplifier Marshall JCM800
# 2                           Drums Ludwig Classic Maple
# 3    Vinyl Record Pink Floyd - The Dark Side of the...
# 4                                 Keyboard Yamaha CP88
# 5                       Electric Bass Fender Precision
# 6                                Microphone Shure SM58
# 7                          Acoustic Guitar Martin D-28
# 8                    Synthesizer Moog Minimoog Model D
# 9                      Electric Guitar Gibson Les Paul
# Name: Guitare, dtype: object

# %%
# Sélection de plusieurs colonnes
df[['Guitare', 'Prix moyen neuf']]
# Out:
#                                              Guitare  Prix moyen neuf
# 0                         Guitar Fender Stratocaster           1500.0
# 1                          Amplifier Marshall JCM800           3200.0
# 2                         Drums Ludwig Classic Maple           4000.0
# 3  Vinyl Record Pink Floyd - The Dark Side of the...           3100.0
# 4                               Keyboard Yamaha CP88           1800.0
# 5                     Electric Bass Fender Precision           1000.0
# 6                              Microphone Shure SM58            150.0
# 7                        Acoustic Guitar Martin D-28           2500.0
# 8                  Synthesizer Moog Minimoog Model D           3000.0
# 9                    Electric Guitar Gibson Les Paul           2000.0

# %%
# Sélection d'une ligne
df.loc[0]
# Out:
# Guitariste                    Freddie Mercury
# Guitare            Guitar Fender Stratocaster
# Prix moyen neuf                        1500.0
# Ville                                   Paris
# Date                               2023-01-05
# Name: 0, dtype: object

# %%
# Sélection de plusieurs lignes
df.loc[1:4]
# Out:
#      Guitariste                                            Guitare  \
# 1  Jimi Hendrix                          Amplifier Marshall JCM800
# 2    Jimmy Page                         Drums Ludwig Classic Maple
# 3   David Bowie  Vinyl Record Pink Floyd - The Dark Side of the...
# 4  Stevie Nicks                               Keyboard Yamaha CP88
#
#    Prix moyen neuf      Ville        Date
# 1           3200.0  Marseille  2023-01-12
# 2           4000.0       Lyon  2023-01-20
# 3           3100.0      Paris  2023-02-02
# 4           1800.0       Nice  2023-02-15

# %%
# Sélection par condition
df[df['Prix moyen neuf'] <= 1500]
# Out:
#           Guitariste                         Guitare  Prix moyen neuf  \
# 0    Freddie Mercury      Guitar Fender Stratocaster           1500.0
# 5  Bruce Springsteen  Electric Bass Fender Precision           1000.0
# 6         Elton John           Microphone Shure SM58            150.0
#
#       Ville        Date
# 0     Paris  2023-01-05
# 5  Bordeaux  2023-02-28
# 6  Toulouse  2023-03-10

# %%
# Modifier l'index du Dataframe. 
df.set_index('Guitariste', inplace=True)
# Cela signifie que la colonne 'Guitariste' sera maintenant utilisée comme labels des lignes.
df
# Out:
#                                                              Guitare  \
# Guitariste
# Freddie Mercury                           Guitar Fender Stratocaster
# Jimi Hendrix                               Amplifier Marshall JCM800
# Jimmy Page                                Drums Ludwig Classic Maple
# David Bowie        Vinyl Record Pink Floyd - The Dark Side of the...
# Stevie Nicks                                    Keyboard Yamaha CP88
# Bruce Springsteen                     Electric Bass Fender Precision
# Elton John                                     Microphone Shure SM58
# Janis Joplin                             Acoustic Guitar Martin D-28
# John Lennon                        Synthesizer Moog Minimoog Model D
# Kurt Cobain                          Electric Guitar Gibson Les Paul
#
#                    Prix moyen neuf      Ville        Date
# Guitariste
# Freddie Mercury             1500.0      Paris  2023-01-05
# Jimi Hendrix                3200.0  Marseille  2023-01-12
# ...

# %%
# Réinitialiser l'index
df.reset_index(inplace=True)
df
# Out:
#           Guitariste                                            Guitare  \
# 0    Freddie Mercury                         Guitar Fender Stratocaster
# 1       Jimi Hendrix                          Amplifier Marshall JCM800
# 2         Jimmy Page                         Drums Ludwig Classic Maple
# 3        David Bowie  Vinyl Record Pink Floyd - The Dark Side of the...
# 4       Stevie Nicks                               Keyboard Yamaha CP88
# 5  Bruce Springsteen                     Electric Bass Fender Precision
# 6         Elton John                              Microphone Shure SM58
# 7       Janis Joplin                        Acoustic Guitar Martin D-28
# 8        John Lennon                  Synthesizer Moog Minimoog Model D
# 9        Kurt Cobain                    Electric Guitar Gibson Les Paul
#
#    Prix moyen neuf      Ville        Date
# 0           1500.0      Paris  2023-01-05
# 1           3200.0  Marseille  2023-01-12
# 2           4000.0       Lyon  2023-01-20
# ...

# %%
# Trier par colonne
df.sort_values('Prix moyen neuf', inplace=True)
df
# Out:
#           Guitariste                                            Guitare  \
# 6         Elton John                              Microphone Shure SM58
# 5  Bruce Springsteen                     Electric Bass Fender Precision
# 0    Freddie Mercury                         Guitar Fender Stratocaster
# 4       Stevie Nicks                               Keyboard Yamaha CP88
# 9        Kurt Cobain                    Electric Guitar Gibson Les Paul
# 7       Janis Joplin                        Acoustic Guitar Martin D-28
# 8        John Lennon                  Synthesizer Moog Minimoog Model D
# 3        David Bowie  Vinyl Record Pink Floyd - The Dark Side of the...
# 1       Jimi Hendrix                          Amplifier Marshall JCM800
# 2         Jimmy Page                         Drums Ludwig Classic Maple
#
#    Prix moyen neuf      Ville        Date
# 6            150.0   Toulouse  2023-03-10
# 5           1000.0   Bordeaux  2023-02-28
# 0           1500.0      Paris  2023-01-05
# ...

# %%
# Filtrer avec plusieurs conditions
df_filtered = df[(df['Prix moyen neuf'] <= 2500) & (df['Ville'] == 'Paris')]
df_filtered
# Out:
#         Guitariste                      Guitare  Prix moyen neuf  Ville  \
# 0  Freddie Mercury   Guitar Fender Stratocaster           1500.0  Paris
# 7     Janis Joplin  Acoustic Guitar Martin D-28           2500.0  Paris
#
#          Date
# 0  2023-01-05
# 7  2023-03-22

# %%
# Créer une nouvelle colonne
df['Année'] = pd.DatetimeIndex(df['Date']).year
df
# Out:
#           Guitariste                                            Guitare  \
# 6         Elton John                              Microphone Shure SM58
# 5  Bruce Springsteen                     Electric Bass Fender Precision
# 0    Freddie Mercury                         Guitar Fender Stratocaster
# 4       Stevie Nicks                               Keyboard Yamaha CP88
# 9        Kurt Cobain                    Electric Guitar Gibson Les Paul
# 7       Janis Joplin                        Acoustic Guitar Martin D-28
# 8        John Lennon                  Synthesizer Moog Minimoog Model D
# 3        David Bowie  Vinyl Record Pink Floyd - The Dark Side of the...
# 1       Jimi Hendrix                          Amplifier Marshall JCM800
# 2         Jimmy Page                         Drums Ludwig Classic Maple
#
#    Prix moyen neuf      Ville        Date  Année
# 6            150.0   Toulouse  2023-03-10   2023
# 5           1000.0   Bordeaux  2023-02-28   2023
# ...

# %%
# Supprimer une colonne
df.drop('Année', axis=1, inplace=True)
df
# Out:
#           Guitariste                                            Guitare  \
# 6         Elton John                              Microphone Shure SM58
# 5  Bruce Springsteen                     Electric Bass Fender Precision
# 0    Freddie Mercury                         Guitar Fender Stratocaster
# 4       Stevie Nicks                               Keyboard Yamaha CP88
# 9        Kurt Cobain                    Electric Guitar Gibson Les Paul
# 7       Janis Joplin                        Acoustic Guitar Martin D-28
# 8        John Lennon                  Synthesizer Moog Minimoog Model D
# 3        David Bowie  Vinyl Record Pink Floyd - The Dark Side of the...
# 1       Jimi Hendrix                          Amplifier Marshall JCM800
# 2         Jimmy Page                         Drums Ludwig Classic Maple
#
#    Prix moyen neuf      Ville        Date
# 6            150.0   Toulouse  2023-03-10
# 5           1000.0   Bordeaux  2023-02-28
# 0           1500.0      Paris  2023-01-05
# ...

# %%
df[(df['Prix moyen neuf'] <= 200) & (df['Ville'] == 'Paris')]
# Out:
# Empty DataFrame
# Columns: [Guitariste, Guitare, Prix moyen neuf, Ville, Date]
# Index: []

# %%
# Supprimer une ligne

# Par exemple nous souhaitons supprimer un élèment intru, le Microphone qui n'est évidemment pas une guitare.

# Trouver l'index de la ligne ou se trouve le microphone
index_to_drop = df[df['Guitare'] == "Microphone Shure SM58"].index

# Supprimer ces lignes du DataFrame
df.drop(index_to_drop, inplace=True)

# Afficher le DataFrame après la suppression
df
# Out:
#           Guitariste                                            Guitare  \
# 5  Bruce Springsteen                     Electric Bass Fender Precision
# 0    Freddie Mercury                         Guitar Fender Stratocaster
# 4       Stevie Nicks                               Keyboard Yamaha CP88
# 9        Kurt Cobain                    Electric Guitar Gibson Les Paul
# 7       Janis Joplin                        Acoustic Guitar Martin D-28
# 8        John Lennon                  Synthesizer Moog Minimoog Model D
# 3        David Bowie  Vinyl Record Pink Floyd - The Dark Side of the...
# 1       Jimi Hendrix                          Amplifier Marshall JCM800
# 2         Jimmy Page                         Drums Ludwig Classic Maple
#
#    Prix moyen neuf      Ville        Date
# 5           1000.0   Bordeaux  2023-02-28
# 0           1500.0      Paris  2023-01-05
# 4           1800.0       Nice  2023-02-15
# 9           2000.0  Marseille  2023-04-18
# ...

# %%
# Grouper les données
df_grouped = df.groupby('Prix moyen neuf').sum()
df_grouped.head()
# Out:
#                         Guitariste                          Guitare  \
# Prix moyen neuf
# 1000.0           Bruce Springsteen   Electric Bass Fender Precision
# 1500.0             Freddie Mercury       Guitar Fender Stratocaster
# 1800.0                Stevie Nicks             Keyboard Yamaha CP88
# 2000.0                 Kurt Cobain  Electric Guitar Gibson Les Paul
# 2500.0                Janis Joplin      Acoustic Guitar Martin D-28
#
#                      Ville        Date
# Prix moyen neuf
# 1000.0            Bordeaux  2023-02-28
# 1500.0               Paris  2023-01-05
# 1800.0                Nice  2023-02-15
# 2000.0           Marseille  2023-04-18
# 2500.0               Paris  2023-03-22

# %%
# Remplacer les valeurs
df.replace({'Ville': {'Paris': 'Paris et Ile-De-France'}}, inplace=True)
df
# Out:
#           Guitariste                                            Guitare  \
# 5  Bruce Springsteen                     Electric Bass Fender Precision
# 0    Freddie Mercury                         Guitar Fender Stratocaster
# 4       Stevie Nicks                               Keyboard Yamaha CP88
# 9        Kurt Cobain                    Electric Guitar Gibson Les Paul
# 7       Janis Joplin                        Acoustic Guitar Martin D-28
# 8        John Lennon                  Synthesizer Moog Minimoog Model D
# 3        David Bowie  Vinyl Record Pink Floyd - The Dark Side of the...
# 1       Jimi Hendrix                          Amplifier Marshall JCM800
# 2         Jimmy Page                         Drums Ludwig Classic Maple
#
#    Prix moyen neuf                   Ville        Date
# 5           1000.0                Bordeaux  2023-02-28
# 0           1500.0  Paris et Ile-De-France  2023-01-05
# 4           1800.0                    Nice  2023-02-15
# ...

# %%
# Renommer les colonnes
df.rename(columns={'Prix moyen neuf': 'Prix'}, inplace=True)
df
# Out:
#           Guitariste                                            Guitare  \
# 5  Bruce Springsteen                     Electric Bass Fender Precision
# 0    Freddie Mercury                         Guitar Fender Stratocaster
# 4       Stevie Nicks                               Keyboard Yamaha CP88
# 9        Kurt Cobain                    Electric Guitar Gibson Les Paul
# 7       Janis Joplin                        Acoustic Guitar Martin D-28
# 8        John Lennon                  Synthesizer Moog Minimoog Model D
# 3        David Bowie  Vinyl Record Pink Floyd - The Dark Side of the...
# 1       Jimi Hendrix                          Amplifier Marshall JCM800
# 2         Jimmy Page                         Drums Ludwig Classic Maple
#
#      Prix                   Ville        Date
# 5  1000.0                Bordeaux  2023-02-28
# 0  1500.0  Paris et Ile-De-France  2023-01-05
# 4  1800.0                    Nice  2023-02-15
# 9  2000.0               Marseille  2023-04-18
# ...

# %%
# Vérifier les valeurs nulles
df.isnull().sum()
# Out:
# Guitariste    0
# Guitare       0
# Prix          0
# Ville         0
# Date          0
# dtype: int64

# %%
# Supprimer les valeurs nulles
df.dropna(inplace=True)
df
# Out:
#           Guitariste                                            Guitare  \
# 5  Bruce Springsteen                     Electric Bass Fender Precision
# 0    Freddie Mercury                         Guitar Fender Stratocaster
# 4       Stevie Nicks                               Keyboard Yamaha CP88
# 9        Kurt Cobain                    Electric Guitar Gibson Les Paul
# 7       Janis Joplin                        Acoustic Guitar Martin D-28
# 8        John Lennon                  Synthesizer Moog Minimoog Model D
# 3        David Bowie  Vinyl Record Pink Floyd - The Dark Side of the...
# 1       Jimi Hendrix                          Amplifier Marshall JCM800
# 2         Jimmy Page                         Drums Ludwig Classic Maple
#
#      Prix                   Ville        Date
# 5  1000.0                Bordeaux  2023-02-28
# 0  1500.0  Paris et Ile-De-France  2023-01-05
# 4  1800.0                    Nice  2023-02-15
# 9  2000.0               Marseille  2023-04-18
# ...

# %%
# Changer le type de données d'une colonne
df['Prix'] = df['Prix'].astype(int)
df
# Out:
#           Guitariste                                            Guitare  Prix  \
# 5  Bruce Springsteen                     Electric Bass Fender Precision  1000
# 0    Freddie Mercury                         Guitar Fender Stratocaster  1500
# 4       Stevie Nicks                               Keyboard Yamaha CP88  1800
# 9        Kurt Cobain                    Electric Guitar Gibson Les Paul  2000
# 7       Janis Joplin                        Acoustic Guitar Martin D-28  2500
# 8        John Lennon                  Synthesizer Moog Minimoog Model D  3000
# 3        David Bowie  Vinyl Record Pink Floyd - The Dark Side of the...  3100
# 1       Jimi Hendrix                          Amplifier Marshall JCM800  3200
# 2         Jimmy Page                         Drums Ludwig Classic Maple  4000
#
#                     Ville        Date
# 5                Bordeaux  2023-02-28
# 0  Paris et Ile-De-France  2023-01-05
# 4                    Nice  2023-02-15
# ...

# %%
# Appliquer une fonction à une colonne - Inflation oblige :) 
df['Prix'] = df['Prix'].apply(lambda x: x * 1.2)
df['Prix']
# Out:
# 5    1200.0
# 0    1800.0
# 4    2160.0
# 9    2400.0
# 7    3000.0
# 8    3600.0
# 3    3720.0
# 1    3840.0
# 2    4800.0
# Name: Prix, dtype: float64

# %%
# Concaténer deux DataFrames
df_new = pd.concat([df, df])
df_new
# Out:
#           Guitariste                                            Guitare  \
# 5  Bruce Springsteen                     Electric Bass Fender Precision
# 0    Freddie Mercury                         Guitar Fender Stratocaster
# 4       Stevie Nicks                               Keyboard Yamaha CP88
# 9        Kurt Cobain                    Electric Guitar Gibson Les Paul
# 7       Janis Joplin                        Acoustic Guitar Martin D-28
# 8        John Lennon                  Synthesizer Moog Minimoog Model D
# 3        David Bowie  Vinyl Record Pink Floyd - The Dark Side of the...
# 1       Jimi Hendrix                          Amplifier Marshall JCM800
# 2         Jimmy Page                         Drums Ludwig Classic Maple
# 5  Bruce Springsteen                     Electric Bass Fender Precision
# 0    Freddie Mercury                         Guitar Fender Stratocaster
# 4       Stevie Nicks                               Keyboard Yamaha CP88
# ...

# %% [markdown]
# ## 3. Exercices - Niveau : ★☆☆
#
# L'entreprise EDF nous a demandé de faire du datacleaning sur ses fichiers qui rassemble des informations sur les centrales nucléaires et leurs efficacité. Seulement voila. Les données qu'on a ne sont pas exploitable en l'état. <br>
#
# 1.   Les données comprennent des informations techniques sur les centrales électriques individuelles, telles que la capacité installée, la principale source d'énergie, le type de technologie, la capacité de cogénération et des informations géographiques.
#
# 2.   La portée géographique se concentre principalement sur l'Allemagne et ses pays voisins, notamment l'Autriche, la Belgique, la Suisse, la République tchèque, le Danemark, l'Espagne, la Finlande, la France, l'Italie, les Pays-Bas, la Norvège, la Pologne, la Suède, la Slovaquie, la Slovénie et le Royaume-Uni.

# %%
# Lire les données
csv_file = "data/powerplants-eu.csv" 

# Step 3 : Lire votre dataframe
df = pd.read_csv(csv_file)

# %%
# Exercice 1

# Afficher les 5 premières lignes du DataFrame
df.head()
# Out:
#                           name         company street postcode city country  \
# 0  Marcinelle Energie (Carsid)  DIRECT ENERGIE    NaN      NaN  NaN      BE
# 1               Aalst Syral GT      Electrabel    NaN      NaN  NaN      BE
# 2               Aalst Syral ST      Electrabel    NaN      NaN  NaN      BE
# 3                    AALTER TJ      Electrabel    NaN      NaN  NaN      BE
# 4            Amercoeur 1 R TGV      Electrabel    NaN      NaN  NaN      BE
#
#    capacity energy_source      technology  chp  ...     type       lat  \
# 0     413.0   Natural gas  Combined cycle  NaN  ...      NaN  50.41396
# 1      43.0   Natural gas     Gas turbine  Yes  ...  CHP/IPP       NaN
# 2       5.0   Natural gas   Steam turbine  Yes  ...  CHP/IPP       NaN
# 3      18.0           Oil     Gas turbine  NaN  ...      NaN       NaN
# 4     451.0   Natural gas  Combined cycle  NaN  ...      NaN  50.43004
#
#        lon          eic_code energy_source_level_1 energy_source_level_2  \
# ...

# %%
df.tail()
# Out:
#          name                        company                  street postcode  \
# 6088  BNA1867                   AVG Köln mbH  Geestemünder Straße 23    50735
# 6089  BNA0492  RAG Anthrazit Ibbenbüren GmbH                     NaN    49477
# 6090  BNA0997        STEAG New Energies GmbH                     NaN    66333
# 6091  BNA1864          KÄMMERER Energie GmbH     Römereschstrasse 33    49084
# 6092  BNA1865          KÄMMERER Energie GmbH     Römereschstrasse 33    49084
#
#                   city country  capacity       energy_source  \
# 6088              Köln      DE      18.0               Waste
# 6089        Ibbenbüren      DE      33.4  Other fossil fuels
# 6090  Völklingen-Fenne      DE      42.0  Other fossil fuels
# 6091         Osnabrück      DE       9.5  Mixed fossil fuels
# 6092         Osnabrück      DE       9.8  Mixed fossil fuels
#
#              technology  chp  ...  type        lat       lon  eic_code  \
# ...

# %%
# Exercice 2

# Afficher les informations générales du DataFrame
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 6093 entries, 0 to 6092
# Data columns (total 21 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   name                   6093 non-null   object
#  1   company                4568 non-null   object
#  2   street                 940 non-null    object
#  3   postcode               4178 non-null   object
#  4   city                   5122 non-null   object
#  5   country                6093 non-null   object
#  6   capacity               6071 non-null   float64
#  7   energy_source          6091 non-null   object
#  8   technology             4962 non-null   object
#  9   chp                    1094 non-null   object
#  10  commissioned           5001 non-null   float64
#  11  type                   271 non-null    object
#  12  lat                    2810 non-null   float64
#  13  lon                    2810 non-null   float64
# ...

# %%
# Exercice 3
# Afficher les statistiques descriptives du DataFrame
df.describe()
# Out:
#           capacity  commissioned          lat          lon
# count  6071.000000   5001.000000  2810.000000  2810.000000
# mean     99.914780   1981.406519    48.991234     8.000150
# std     238.665615     27.990000     5.016405     7.158185
# min       0.000000   1899.000000    36.182641    -8.849735
# 25%       1.500000   1962.000000    46.373050     6.178273
# 50%      12.000000   1987.000000    48.569053     8.431095
# 75%      71.000000   2005.000000    51.523252    11.581494
# max    3446.000000   2020.000000    67.729796    30.426259

# %% [markdown]
# ## 3. Exercices - Niveau : ★★☆

# %%
# Remplacer toutes les valeurs NaN par 0
df.fillna(0)
# Out:
#                              name                        company  \
# 0     Marcinelle Energie (Carsid)                 DIRECT ENERGIE
# 1                  Aalst Syral GT                     Electrabel
# 2                  Aalst Syral ST                     Electrabel
# 3                       AALTER TJ                     Electrabel
# 4               Amercoeur 1 R TGV                     Electrabel
# ...                           ...                            ...
# 6088                      BNA1867                   AVG Köln mbH
# 6089                      BNA0492  RAG Anthrazit Ibbenbüren GmbH
# 6090                      BNA0997        STEAG New Energies GmbH
# 6091                      BNA1864          KÄMMERER Energie GmbH
# 6092                      BNA1865          KÄMMERER Energie GmbH
#
#                       street postcode              city country  capacity  \
# 0                          0        0                 0      BE     413.0
# ...

# %% [markdown]
# <details>
#     <summary> Indice 🕵️ </summary>
# <p>
# Vous devriez utiliser la méthode fillna() sur votre dataframe. Cette méthode remplace toutes les valeurs NaN par la valeur que vous spécifiez.
# </details>
# <details>
#     <summary> Voir la réponse 🔮 </summary>
# <p>
# <pre>
# # Remplacer toutes les valeurs NaN par 0
# df = df.fillna(0)
# </pre>
# </details>

# %%
# Remplacer toutes les valeurs NaN dans la colonne 'capacity' par la moyenne de cette colonne
df["capacity"].fillna(df["capacity"].mean(), inplace=True)
df.head()
# Out:
# /tmp/ipykernel_482/3383787438.py:2: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df["capacity"].fillna(df["capacity"].mean(), inplace=True)
#                           name         company street postcode city country  \
# 0  Marcinelle Energie (Carsid)  DIRECT ENERGIE    NaN      NaN  NaN      BE
# 1               Aalst Syral GT      Electrabel    NaN      NaN  NaN      BE
# 2               Aalst Syral ST      Electrabel    NaN      NaN  NaN      BE
# ...

# %% [markdown]
# <details>
#     <summary> Indice 🕵️ </summary>
# <p>
# Pour remplacer les valeurs NaN dans une colonne spécifique par la moyenne de cette colonne, vous devriez utiliser fillna() avec la méthode mean() de cette colonne. N'oubliez pas d'utiliser inplace=True pour effectuer le changement directement sur le DataFrame.
#
# </details>
# <details>
#     <summary> Voir la réponse 🔮 </summary>
# <p>
# <pre>
# # Remplacer toutes les valeurs NaN dans la colonne 'capacity' par la moyenne de cette colonne
# df['capacity'].fillna(df['capacity'].mean(), inplace=True)
# df.head()
# </pre>
# </details>

# %%
# Créer un histogramme de la colonne 'capacity'
df['capacity'].plot(kind='hist')
df.head()
# Out:
#                           name         company street postcode city country  \
# 0  Marcinelle Energie (Carsid)  DIRECT ENERGIE    NaN      NaN  NaN      BE
# 1               Aalst Syral GT      Electrabel    NaN      NaN  NaN      BE
# 2               Aalst Syral ST      Electrabel    NaN      NaN  NaN      BE
# 3                    AALTER TJ      Electrabel    NaN      NaN  NaN      BE
# 4            Amercoeur 1 R TGV      Electrabel    NaN      NaN  NaN      BE
#
#    capacity energy_source      technology  chp  ...     type       lat  \
# 0     413.0   Natural gas  Combined cycle  NaN  ...      NaN  50.41396
# 1      43.0   Natural gas     Gas turbine  Yes  ...  CHP/IPP       NaN
# 2       5.0   Natural gas   Steam turbine  Yes  ...  CHP/IPP       NaN
# 3      18.0           Oil     Gas turbine  NaN  ...      NaN       NaN
# 4     451.0   Natural gas  Combined cycle  NaN  ...      NaN  50.43004
#
#        lon          eic_code energy_source_level_1 energy_source_level_2  \
# ...

# %% [markdown]
# <details>
#     <summary> Indice 🕵️ </summary>
# <p>
# Pour créer un histogramme d'une colonne spécifique, vous pouvez utiliser la méthode plot() avec l'argument 'kind' défini sur 'hist'. Cela générera un histogramme de la colonne sélectionnée.
# </details>
# <details>
#     <summary> Voir la réponse 🔮 </summary>
# <p>
# <pre>
# # Créer un histogramme de la colonne 'capacity'
# df['capacity'].plot(kind='hist')
# df.head()
# </pre>
# </details>

# %% [markdown]
# ## 3. Exercices - Niveau : ★★★

# %%
# Afficher le nombre de centrales électriques par type d'énergie

nombre_cent = df['energy_source'].value_counts()
nombre_cent
# Out:
# energy_source
# Hydro                                  4098
# Natural gas                             540
# Hard coal                               507
# Lignite                                 212
# Biomass and biogas                      156
# Mixed fossil fuels                      142
# Oil                                     124
# Nuclear                                 121
# Waste                                    81
# Other fuels                              46
# Non-renewable waste                      39
# Other or unspecified energy sources      11
# Other fossil fuels                       11
# Bioenergy                                 3
# Name: count, dtype: int64

# %% [markdown]
# <details>
#     <summary> Indice 🕵️ </summary>
# <p>
#
# Utilisez la méthode value_counts() sur la colonne `energy_source`. Cela comptera le nombre de chaque valeur unique dans cette colonne.
# </details>
# <details>
#     <summary> Voir la réponse 🔮 </summary>
# <p>
# <pre>
# # Afficher le nombre de centrales électriques par type d'énergie
# df['energy_source'].value_counts()
# </pre>
# </details>

# %%
# Affichez les cinq premières centrales électriques ayant la plus grande capacité
df.nlargest(5, 'capacity')
# Out:
#                       name     company street postcode                city  \
# 1331         MONTALTO C.LE         NaN    NaN      NaN  MONTALTO DI CASTRO
# 2867  Drax - biomass units  Drax Power    NaN      NaN                 NaN
# 1352       BRINDISI SUD CE         NaN    NaN      NaN            BRINDISI
# 2960              Pembroke  RWE Npower    NaN      NaN                 NaN
# 1298           PORTO TOLLE         NaN    NaN      NaN         PORTO TOLLE
#
#      country  capacity       energy_source technology  chp  ...  type  \
# 1331      IT    3446.0  Mixed fossil fuels        NaN  NaN  ...   NaN
# 2867      UK    2640.0  Biomass and biogas        NaN  NaN  ...   NaN
# 1352      IT    2446.8  Mixed fossil fuels        NaN  NaN  ...   NaN
# 2960      UK    2199.0         Natural gas        NaN  NaN  ...   NaN
# 1298      IT    2140.0  Mixed fossil fuels        NaN  NaN  ...   NaN
#
#             lat        lon          eic_code energy_source_level_1  \
# ...

# %% [markdown]
# <details>
#     <summary> Indice 🕵️ </summary>
# <p>
#
# Utilisez la méthode nlargest() sur votre dataframe. Cela retournera les lignes avec les plus grandes valeurs dans la colonne spécifiée.
#
# </details>
# <details>
#     <summary> Voir la réponse 🔮 </summary>
# <p>
# <pre>
# # Afficher les cinq premières centrales électriques ayant la plus grande capacité
# df.nlargest(5, 'capacity')
# </pre>
# </details>

# %%
# Calculer la capacité totale par pays
capa_pays = df.groupby("country").sum()
capa_pays.head()
# Out:
#                                                       name  \
# country
# AT       Abwinden-AstenAltenmarktAltenwörthAnnabrückeAr...
# BE       Marcinelle Energie (Carsid)Aalst Syral GTAalst...
# CH       Val GiufVal StremSedrun 1Sedrun 2Tavanasa (KVR...
# CZ       Alpiq‐ECK 7Alpiq‐ECK B5Alpiq‐ECK B7C.Budejovic...
# DE       BNA0012aBNA0021BNA0027BNA0055BNA0062BNA0066BNA...
#
#                                                    company  \
# country
# AT       VERBUND Thermal Power GmbH & Co KGEVN AGWien E...
# BE       DIRECT ENERGIEElectrabelElectrabelElectrabelEl...
# CH       BKW FMB Energie AGKernkraftwerk Gösgen-Däniken...
# CZ                                                       0
# DE       Sappi Alfeld GmbHHeizkraftwerk Altenstadt GmbH...
#
#                                                     street  \
# country
# AT       WeiÃeneggweg 1Ludwig BrucknerstraÃe 1Haidequ...
# BE                                                       0
# ...

# %% [markdown]
# <details>
#     <summary> Indice 🕵️ </summary>
# <p>
# <pre>
# Pour calculer la somme d'une colonne pour chaque valeur unique d'une autre colonne, utilisez la méthode groupby() suivie de sum() sur la colonne d'intérêt.
# </pre>
# </details>
# <details>
#     <summary> Voir la réponse 🔮 </summary>
# <p>
# <pre>
# # Calculer la capacité totale par pays
# df.groupby('country')['capacity'].sum()
# </pre>
# </details>

# %%
# Créer un graphique à barres montrant la capacité totale par pays
df.groupby('country')['capacity'].sum().plot(kind='bar')
# Out:
# <Axes: xlabel='country'>

# %% [markdown]
# <details>
#     <summary> Indice 🕵️ </summary>
# <p>
#
# Après avoir regroupé les données par pays et calculé la somme des capacités, utilisez la méthode plot() avec l'argument 'kind' défini sur 'bar'. Cela créera un graphique à barres de la capacité totale par pays.
# </details>
# <details>
#     <summary> Voir la réponse 🔮 </summary>
# <p>
# <pre>
# # Créer un graphique à barres montrant la capacité totale par pays
# df.groupby('country')['capacity'].sum().plot(kind='bar')
# </pre>
# </details>
