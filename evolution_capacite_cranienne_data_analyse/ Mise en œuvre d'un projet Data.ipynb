# %% [markdown]
# <div style="border: 0px solid blue; padding: 10px;"><img src="https://asset.brandfetch.io/idvDrMBg3m/idgDR62lX4.png" alt="Logo Data Rockstars" width="274" height="80"><h3 style="color: #333;">🔒 Le contenu de ce document est confidentiel. 📝</h3><p><em>Le contenu de ce document est confidentiel et la copie ou la distribution est interdite.</em> 😶‍🌫️</p><p>📧 Pour toute question, veuillez nous contacter à <a href="mailto:contact@datarockstars.ai">contact@datarockstars.ai</a></p><hr style="border-top: 1px solid blue;"><h1>Le programme du notebook</h1><strong>📖 Au programme</strong><ul><li>Challenge en full autonomie, un peu comme dans la vraie vie finalement !</li></ul><hr style="border-top: 1px solid blue;"><p>🔰 Démarrez en exécutant chaque segment de code un à un et en analysant les résultats affichés.</p><hr style="border-top: 1px solid blue;"><p>A vous de jouer 😎✌️</p></div>

# %% [markdown]
# <div style="border:2px solid red; padding: 10px; background-color: #FFF4F8;">
#     <p style="color: red;"><strong>⚠️ Soumettre votre challenge à la fin de chaque module ⚠️</strong></p>
#     <ul>
#         <li>💾 Avant de soumettre le lab, pensez à bien <strong> télécharger votre Jupyter notebook</strong> en cliquant sur <em>Fichier > Download.</em>.</li>
#         <li>✏️ Seul le notebook <code>main.ipynb</code> sera sauvegardé et envoyé pour évaluation à vos professeurs. Si vous avez d'autres notebooks, ils ne seront <strong>pas comptabilisés. </strong></li>
#         <li>🚫 Une fois que vous avez soumis votre travail, vous ne pourrez plus le modifier. Vous aurez cependant, la possibilité de faire une nouvelle tentative autant de fois que souhaité.</li>
#     </ul>
#     <p>Assurez-vous de vérifier vos fichiers avant de procéder !</p>
# </div>

# %% [markdown]
# # Gestion de Projet Agile avec SCRUM: Projet Fil Rouge
#
# ## Objectif
#
# Appliquer les principes de la gestion de projet agile, en particulier la méthode SCRUM, dans le cadre de votre projet fil rouge.

# %% [markdown]
# <div style="border:2px solid #4CAF50; padding: 10px; background-color: #ebf9eb;">
#     <h3 style="color: #4CAF50;">💡 Astuce</h3>
#     <p><strong>Ecrire en markdown</strong></p>
#     <p>Si vous avez besoin d'aide pour écrire en markdown, rendez-vous ici pour vous familiariser avec la syntaxe : <a href="https://www.markdownguide.org/basic-syntax/" target="_blank">https://www.markdownguide.org/basic-syntax/</a></p>
# </div>

# %% [markdown]
# ### 1. Choix du jeu de données : A faire avant la fin du module ! ⏰

# %% [markdown]
# - Avant de commencer la déclinaison de votre projet, nous vous invitons à compléter le formulaire suivant : [Choix projet Fil Rouge](https://docs.google.com/forms/d/e/1FAIpQLSe3xts57ZVVKF8RWNl7Yo-5dg87J5gf-pO_yRbi_gY4MOJBzA/viewform?usp=sf_link)

# %% [markdown]
# _🧑🏻‍💻 Votre réponse ici_

# %% [markdown]
# Jeu de données sélectionné :
#
# Le jeu de données utilisé est "Evolution_DataSets.csv", car il rassemble une grande variété d'informations sur les spécimens humains et préhumains.
# Il permet d'explorer l'évolution morphologique, la répartition géographique et les facteurs biologiques et culturels associés à l'espèce humaine.
# Ce jeu de données est particulièrement adapté à l’étude de l’évolution de traits comme la capacité crânienne à travers le temps et l’espace.

# %% [markdown]
# ### 2. Cadrage du projet (Sprint 0)

# %% [markdown]
# - **Définition du projet:** Déterminez le sujet, les objectifs, et les livrables attendus.

# %% [markdown]
# _🧑🏻‍💻 Votre réponse ici_
#
# Analyse de l’évolution de la capacité crânienne chez les spécimens humains et préhumains à partir d’un jeu de données paléoanthropologiques.
#
#  Objectifs :
# Identifier les facteurs (anatomiques, comportementaux, environnementaux, temporels) influençant la capacité crânienne.
#
# Étudier les corrélations entre la capacité crânienne et d’autres variables physiques (taille, bipédie, alimentation, etc.).
#
# Analyser l’évolution temporelle et la répartition géographique de ce trait.
#
# Fournir une visualisation claire des tendances et des relations majeures.
#
#  Livrables attendus :
# Un notebook Python structuré (exploration, visualisation, analyse)
#
# Un rapport synthétique présentant les résultats, interprétations et limites
#
# Un ensemble de graphiques pertinents (boxplots, heatmaps, scatterplots, etc.)
#
# (Optionnel) Un modèle prédictif ou une analyse de clustering

# %% [markdown]
# ### Sujet du Projet
# Analyse morpho-évolutive des spécimens humains à travers le temps et l’espace.
#
# Ce projet vise à étudier comment les traits morphologiques — en particulier la capacité crânienne — ont évolué au fil du temps chez les spécimens humains et préhumains, en lien avec leurs caractéristiques anatomiques, comportementales, environnementales et géographiques.
#
# ### Objectifs du Projet
# 1. Analyser l’évolution de la capacité crânienne dans le temps :
# Étudier les variations de la capacité crânienne selon l’âge des spécimens (Time), et identifier les grandes étapes évolutives de l’humanité.
#
# 2. Comparer la morphologie selon les espèces et les zones :
# Observer comment des traits comme la taille, la posture, ou la bipédie varient selon les espèces (Genus_&_Specie) et les zones géographiques (Zone, Current_Country).
#
# 3. Évaluer l’influence des facteurs environnementaux et comportementaux :
# Étudier l’impact de facteurs comme le régime alimentaire, l'habitat, la technologie ou la migration sur la capacité crânienne et d'autres traits associés.
#
# 4. Identifier les combinaisons de traits associées aux profils les plus évolués :
# Repérer les configurations morphologiques (taille, posture, régime, outils…) associées aux cerveaux les plus développés et modéliser les relations sous-jacentes.
#
# ### Livrables Attendus
#  Rapport d’analyse détaillé :
# Document complet incluant la problématique, les hypothèses, la méthodologie, les analyses statistiques, les visualisations, les résultats et interprétations.
#
# Visualisations morphologiques et temporelles :
# Graphiques montrant l’évolution de la capacité crânienne dans le temps.
#
# Boxplots comparatifs des traits morphologiques par espèce, zone, ou régime.
#
# Heatmaps de corrélation entre les variables quantitatives.
#
#  Code et Notebook documenté :
# Notebook Python complet contenant :
#
# Nettoyage des données
#
# Visualisations (Seaborn, Matplotlib)
#
# Analyses statistiques
#
# Modélisation des facteurs influents
#
# Tableaux et synthèses :
# Tableau récapitulatif des moyennes morphologiques par espèce
#
# Résumés des corrélations entre traits
#
# Liste des variables les plus fortement liées à la capacité crânienne
#
# Ce plan permet de comprendre l’évolution humaine sous un angle quantitatif, en croisant morphologie, environnement, et comportement, tout en mettant en valeur les étapes clés de cette transformation dans le temps.

# %% [markdown]
# - **Identification des besoins:** Identifiez les besoins en données et les ressources nécessaires.

# %% [markdown]
# _🧑🏻‍💻 Votre réponse ici_

# %% [markdown]
# ### Besoins en Données
#  Données anthropologiques :
# Utilisation du fichier "Evolution_DataSets.csv", qui rassemble des informations détaillées sur des spécimens humains et préhumains : capacité crânienne, taille, époque d’apparition (Time), caractéristiques anatomiques, comportements (bipédie, alimentation), et origine géographique. Ce fichier constitue la base principale du projet.
#
# ### Données temporelles :
# Les données incluent une estimation de l’ancienneté des spécimens (en millions d’années) permettant d’analyser l’évolution morphologique à travers le temps, depuis les premiers homininés jusqu’à l’Homme moderne.
#
#  Données géographiques :
# Des champs tels que Current_Country et Zone permettent de relier les spécimens à leur répartition spatiale, et d’analyser les éventuelles variations régionales (climat, habitat, migrations).
#
#  Données comportementales et culturelles :
# Les colonnes Diet, biped, Tecno, Habitat, etc. fournissent des informations sur le mode de vie, les capacités technologiques et les adaptations environnementales des espèces.
#
# Ressources Nécessaires
#  Outils logiciels et environnement de développement :
# IDE ou Jupyter Notebook pour le traitement de données avec Python.
#
# Bibliothèques Python :
#
# Pandas, NumPy pour la manipulation des données
#
# Seaborn, Matplotlib, Plotly pour les visualisations (boxplots, courbes, scatterplots, heatmaps…)
#
# (Optionnel) Scikit-learn pour la modélisation ou le clustering
#
#  Infrastructure informatique :
# Un poste de travail avec une mémoire suffisante pour gérer un dataset de 12 000 lignes × 28 colonnes.
#
# En cas d’analyse plus lourde (modélisation, clustering), possibilité de recourir à un environnement cloud (ex. Google Colab, AWS).
#
# Expertise et ressources humaines :
# Compétences en data analyse, statistiques, visualisation.
#
# Connaissances utiles en paléoanthropologie ou biologie évolutive pour bien interpréter les résultats (espèces, traits fonctionnels, anatomie comparée).
#
#  Documentation et collaboration :
# Documentation du jeu de données (dictionnaire des variables, unités…)
#
# Outils de travail collaboratif recommandés : GitHub pour le versioning, Notion/Trello pour l’organisation, et éventuellement Slack pour la communication d’équipe.

# %% [markdown]
# - **Backlog de produit:** Créez un backlog de produit initial.

# %% [markdown]
# _🧑🏻‍💻 Votre réponse ici_

# %% [markdown]
# 1. Chargement et Exploration Initiale du Dataset
# User Story :
#
# En tant qu’analyste, je souhaite charger le jeu de données Evolution_DataSets.csv afin d’examiner sa structure, ses colonnes, et sa qualité initiale.
#
# Tâches :
#
# Importer le fichier dans Python (Pandas).
#
# Afficher les premières lignes et la liste des colonnes.
#
# Identifier les types de données et repérer les valeurs manquantes.
#
# Priorité : Élevée
#
#  2. Préparation et Nettoyage des Données
# User Story :
#
# En tant qu’analyste, je veux nettoyer les données pour corriger les erreurs, traiter les valeurs manquantes et convertir les colonnes mal typées pour assurer une analyse fiable.
#
# Tâches :
#
# Détecter et gérer les valeurs manquantes ou aberrantes (Time, Cranial_Capacity, etc.).
#
# Convertir les types de colonnes (float, category, etc.).
#
# Supprimer les doublons éventuels et standardiser les noms de colonnes.
#
# Priorité : Élevée
#
# 3. Analyse Temporelle de l’Évolution Humaine
# User Story :
#
# En tant qu’analyste, je veux étudier l’évolution de la capacité crânienne dans le temps afin d’identifier les grandes tendances évolutives.
#
# Tâches :
#
# Créer des courbes Time vs Cranial_Capacity.
#
# Détecter les éventuelles ruptures ou paliers évolutifs.
#
# Segmenter les données par époque ou espèces dominantes.
#
# Priorité : Élevée
#
# 4. Analyse Morphologique par Espèce
# User Story :
#
# En tant qu’analyste, je souhaite comparer les caractéristiques physiques (taille, capacité crânienne, posture…) entre les différentes espèces.
#
# Tâches :
#
# Tracer des boxplots par espèce (Genus_&_Specie).
#
# Comparer les distributions de Cranial_Capacity, Height, etc.
#
# Identifier les espèces avec les profils morphologiques les plus évolués.
#
# Priorité : Moyenne
#
#  5. Analyse Géographique de l’Évolution
# User Story :
#
# En tant qu’utilisateur, je souhaite visualiser la répartition géographique des spécimens pour analyser les variations morphologiques par zone ou pays.
#
# Tâches :
#
# Regrouper les données par Zone ou Current_Country.
#
# Créer des cartes ou heatmaps des moyennes de capacité crânienne.
#
# Mettre en évidence les zones avec des profils extrêmes.
#
# Priorité : Moyenne
#
#  6. Analyse des Facteurs Comportementaux et Environnementaux
# User Story :
#
# En tant qu’analyste, je veux étudier comment des facteurs comme la bipédie, le régime alimentaire, ou la technologie influencent la capacité crânienne.
#
# Tâches :
#
# Corréler Diet, biped, Tecno_type, Habitat avec Cranial_Capacity.
#
# Utiliser des boxplots ou scatterplots catégoriels.
#
# Détecter les combinaisons comportement/morphologie les plus marquantes.
#
# Priorité : Moyenne
#
# 7. Visualisation et Présentation des Résultats
# User Story :
#
# En tant qu’utilisateur, je veux générer des visualisations claires et un rapport synthétique pour communiquer les résultats de l’analyse.
#
# Tâches :
#
# Créer des graphes (scatter, box, heatmap, timelines).
#
# Compiler les résultats dans un notebook documenté.
#
# Rédiger un rapport illustré pour interprétation.
#
# Priorité : Élevée
#
# 8. (Optionnel) Modélisation et Clustering
# User Story :
#
# En tant qu’analyste, je souhaite modéliser les facteurs qui prédisent la capacité crânienne et explorer des regroupements d’individus similaires.
#
# Tâches :
#
# Construire une régression linéaire ou un arbre de décision.
#
# Appliquer un clustering (K-Means) basé sur les variables morphologiques.
#
# Visualiser les clusters en 2D/3D.
#
# Priorité : Moyenne
#
#  9. Synthèse et Recommandations d’Interprétation
# User Story :
#
# En tant qu’analyste, je souhaite formuler des conclusions sur les facteurs les plus déterminants de l’évolution humaine.
#
# Tâches :
#
# Résumer les tendances majeures.
#
# Identifier les facteurs explicatifs forts (zone, posture, alimentation...).
#
# Suggérer des pistes d’interprétation biologique ou évolutionniste.
#
# Priorité : Moyenne

# %% [markdown]
# ### 3. Planification des Sprints

# %% [markdown]
# - **Découpage en Sprints:** Divisez le projet en plusieurs sprints (itérations de travail).

# %% [markdown]
# - **Objectifs et tâches:** Pour chaque sprint, définissez des objectifs spécifiques et sélectionnez des tâches du backlog de produit.

# %% [markdown]
# _🧑🏻‍💻 Votre réponse ici_

# %% [markdown]
# Sprint 1 : Exploration et Préparation des Données
#  Objectifs :
# Charger et explorer le jeu de données Evolution_DataSets.csv.
#
# Examiner la structure, identifier les variables importantes, les valeurs manquantes, les types de données.
#
# Nettoyer et préparer les données pour des analyses morphologiques, temporelles et géographiques.
#
#  Tâches :
# Importer le fichier CSV dans l’environnement Python (ex. Jupyter Notebook).
#
# Afficher les premières lignes et la liste des colonnes.
#
# Dresser un bilan des types (object, float, etc.), valeurs manquantes, doublons ou incohérences.
#
# Convertir les types mal formatés (Time, Cranial_Capacity, Height, etc.).
#
# Standardiser les noms de colonnes et les formats (ex. category, float, etc.).
#
# Créer des colonnes dérivées si nécessaire (Time_bin, variables normalisées, etc.).
#
# Sprint 2 : Analyse Temporelle, Morphologique et Spatiale
#  Objectifs :
# Étudier l’évolution de la capacité crânienne et d’autres traits morphologiques dans le temps.
#
# Comparer les profils morphologiques par espèce et par zone géographique.
#
# Identifier les espèces ou périodes clés marquant des transitions évolutives.
#
#  Tâches :
# Créer des courbes temporelles (Time vs Cranial_Capacity), avec régression ou segmentation.
#
# Réaliser des boxplots par espèce (Genus_&_Specie) pour comparer Height, Cranial_Capacity, etc.
#
# Grouper les spécimens par Zone, Current_Country, ou Habitat, puis analyser les moyennes.
#
# Utiliser des scatterplots ou heatmaps pour observer les relations entre variables physiques.
#
# Repérer les espèces ou groupes affichant des changements marquants ou des anomalies.
#
#  Sprint 3 : Analyse des Facteurs Comportementaux et Synthèse des Résultats
#  Objectifs :
# Étudier l’influence des facteurs comportementaux et environnementaux sur l’évolution morphologique (ex. alimentation, bipédie, technologie).
#
# Identifier les combinations de traits les plus liées à un développement cérébral élevé.
#
# Compiler les résultats pour produire une synthèse cohérente et visuellement claire.
#
# Tâches :
# Analyser les relations entre Diet, biped, Tecno_type, Habitat et Cranial_Capacity.
#
# Réaliser des analyses statistiques (corrélations, groupby, éventuellement régression).
#
# Produire des visualisations synthétiques (heatmaps, scatterplots 2D/3D).
#
# Élaborer un rapport complet : méthodologie, analyses, visualisations, interprétations.
#
# Préparer une présentation finale avec les insights clés sur l’évolution humaine et les facteurs majeurs.

# %% [markdown]
# ### 4. Exécution du premier Sprint
#
# - **Travail sur les tâches:** Concentrez-vous sur les tâches sélectionnées durant le premier sprint.
# - **Suivi quotidien:** Effectuez un suivi quotidien de l'avancement via un stand-up quotidien virtuel.

# %% [markdown]
# _🧑🏻‍💻 Votre réponse ici_

# %% [markdown]
# Sprint 1 : Exploration et Préparation des Données
#  Chargement et Exploration Initiale du Dataset
#  Tâches :
# Importer le CSV :
# Charger le fichier Evolution_DataSets.csv dans l’environnement Python (Jupyter Notebook recommandé).
#
# Affichage et Analyse Préliminaire :
# Afficher les premières lignes (df.head()), la structure du dataset (df.info(), df.describe()), et la liste des colonnes pour examiner les types de données :
#
# Variables quantitatives : Cranial_Capacity, Height, Time
#
# Variables catégorielles : Diet, Zone, Genus_&_Specie, etc.
#
# Évaluer la qualité des données :
#
# Identifier les valeurs manquantes (df.isnull().sum()),
#
# Détecter d’éventuels doublons (df.duplicated()),
#
# Repérer les incohérences de formats ou de nommage (espaces, parenthèses, caractères spéciaux, etc.).
#
#  Préparation et Nettoyage des Données
#  Tâches :
# Traitement des valeurs manquantes :
# Imputation (ex. par la moyenne) ou suppression selon le contexte et l’importance de la variable (ex. conserver Cranial_Capacity, supprimer les lignes sans Time si trop peu nombreuses).
#
# Gestion des doublons :
# Suppression des entrées redondantes pour ne pas biaiser les moyennes ou les distributions.
#
# Standardisation des formats :
#
# Conversion de colonnes object en float, category, etc.
#
# Nettoyage des noms de colonnes (str.strip(), str.replace())
#
# Transformation des unités si nécessaire (ex. normalisation de Height, création de Time_bin)
#
#  Outils et Coordination
#  Outils recommandés :
# Outils d’analyse : Python, Jupyter, Pandas, Seaborn, Matplotlib
#
# Outils de communication : Slack, Microsoft Teams, Discord (selon l’équipe)
#
# Suivi du backlog : Trello, Notion, ou Jira pour visualiser l’avancement et assigner les tâches
#
#  Suivi Quotidien : Stand-Up Virtuel
#  Fréquence :
# Réunion rapide chaque matin (15 min max).
#
#  Format de tour de table :
# Ce qui a été accompli la veille :
# "J'ai nettoyé les colonnes Cranial_Capacity et Height, et supprimé les doublons."
#
# Ce qui est prévu aujourd’hui :
# "Je vais convertir Time en numérique, vérifier les outliers, et créer les tranches temporelles (Time_bin)."
#
# Obstacles rencontrés :
# "J’ai un doute sur l’interprétation de certaines valeurs faibles de Time (<0.01), je voudrais en discuter."

# %% [markdown]
# ### 5. Revue et rétrospective de Sprint
#
# - **Évaluation des résultats :** À la fin du Sprint, évaluez ce qui a été accompli et présentez les résultats.
# - **Analyse et ajustements :** Analysez les succès et les défis rencontrés, ajustez la stratégie si nécessaire.

# %% [markdown]
# _🧑🏻‍💻 Votre réponse ici_

# %% [markdown]
# 1. Présentation des Résultats Accomplis
# Récapitulatif des Tâches Réalisées
# Chargement et Exploration des Données :
# Le fichier Evolution_DataSets.csv a été importé avec succès dans l’environnement Python.
#
# Les premières lignes du jeu de données ont été affichées et la structure globale a été analysée.
#
# Les types de variables (quantitatives : Cranial_Capacity, Height, Time / qualitatives : Diet, biped, Zone, etc.) ont été identifiés.
#
# Un premier diagnostic des valeurs manquantes et colonnes à nettoyer a été réalisé.
#
# Nettoyage des Données et Gestion des Valeurs Aberrantes :
# Les valeurs manquantes ont été recensées, et une stratégie de traitement a été appliquée selon l’importance de la variable (ex : suppression des lignes sans Cranial_Capacity, conservation de Height avec NaN).
#
# Les doublons ont été détectés et supprimés pour garantir l’intégrité des analyses.
#
# Les valeurs aberrantes ont été identifiées à l’aide de méthodes statistiques (écart interquartile, z-score) sur les variables clés (Time, Height, Cranial_Capacity).
#
# Les formats de colonnes ont été uniformisés : conversion en float, int, category, renommage cohérent des variables (Time (Ma) → Time, etc.).
#
# Visualisation Initiale et Synthèse :
# Des histogrammes, boxplots et heatmaps ont permis de visualiser la distribution des variables et d’identifier des relations ou anomalies.
#
# Une première base d’analyse propre a été créée, prête pour les sprints suivants.
#
# 2. Analyse et Ajustements
# Succès du Sprint :
# L’exploration initiale a permis une bonne compréhension du contenu, des variables et de la structure du dataset.
#
# Le nettoyage des doublons, la conversion des types et la gestion des valeurs extrêmes ont été traités avec rigueur.
#
# La capacité crânienne, cœur du projet, est désormais exploitable sans obstacle technique.
#
# La mise en place de visualisations simples a fourni une base claire pour les comparaisons morphologiques futures.
#
# Le stand-up quotidien a assuré un bon rythme de travail et a permis de résoudre les difficultés techniques rapidement.
#
# Défis et Points d’Amélioration :
# Le format de certaines colonnes (Time, parenthèses et unités) a nécessité plus de temps que prévu pour être nettoyé.
#
# Quelques variables peu renseignées (comme certaines catégories anatomiques ou technologiques) ont soulevé la question de leur utilité dans l’analyse.
#
# La gestion des valeurs aberrantes s’est révélée complexe pour Time en raison de sa large échelle (de quelques centaines d’années à 7 millions d’années).
#
# Anticipation de futurs problèmes d’intégration si d'autres jeux de données sont ajoutés (climatiques, comparatifs externes).
#
# Ajustements Stratégiques Proposés
#  Affinement des Méthodes de Standardisation :
# Renforcer les scripts de nettoyage en automatisant la détection des colonnes mal formatées.
#
# Créer un script de validation post-cleaning avec affichage des types et taux de complétude.
#
#  Documentation des Procédures :
# Documenter les étapes de nettoyage, les règles d’imputation, et les méthodes d’identification des outliers.
#
# Conserver une trace des décisions de suppression ou de transformation (en markdown ou notebook).
#
#  Préparation de l’Analyse Temporelle et Comportementale :
# Définir des tranches temporelles (Time_bin) cohérentes pour l’analyse évolutive.
#
# Préparer des mappings (Diet, Tecno_type, etc.) pour les visualisations par catégorie.
#
# Formation et Partage de Connaissances :
# Organiser une séance courte de partage sur la gestion de l'hétérogénéité des données morphologiques.
#
# Réviser ensemble les outils de visualisation les plus pertinents pour les prochaines étapes.

# %% [markdown]
# ### 6. Restitution
#
# - **Compte-rendu:** Rédigez un compte-rendu rendant compte des différents aspects du Framework SCRUM appliqués à votre projet fil rouge.

# %% [markdown]
# _🧑🏻‍💻 Votre réponse ici_

# %% [markdown]
#  1. Définition du Cadre et du Projet
#  Contexte du Projet :
# Le projet fil rouge porte sur l’analyse morphologique de l’évolution humaine, en s’appuyant sur le dataset Evolution_DataSets.csv.
# L’objectif est de comprendre quels facteurs anatomiques, comportementaux, environnementaux ou géographiques influencent la capacité crânienne des spécimens humains et préhumains, et comment cette variable a évolué dans le temps.
#
# Adoption de SCRUM :
# Le cadre SCRUM a été adopté pour structurer le travail par itérations (sprints), permettre une réactivité aux découvertes successives, et favoriser la collaboration active au sein de l’équipe.
# Chaque sprint a été défini avec des objectifs précis (nettoyage, analyse temporelle, modélisation), permettant de valider progressivement les hypothèses d’évolution humaine.
#
# 2. Backlog de Produit et Planification
#  Création du Backlog :
# Le backlog a été structuré en user stories et tâches prioritaires, couvrant :
#
# L’exploration et la préparation des données (Cranial_Capacity, Time, Height)
#
# L’analyse des facteurs influents (Diet, biped, Zone, etc.)
#
# La modélisation éventuelle des prédicteurs de l’évolution crânienne
#
# Chaque tâche a été priorisée selon sa valeur analytique et son rôle dans la compréhension des phénomènes évolutifs.
#
#  Planification des Sprints :
# Sprint 1 : Chargement, exploration et nettoyage des données (types, valeurs manquantes, doublons, standardisation des formats).
#
# Sprint 2 : Analyse temporelle et géographique (évolution de la capacité crânienne par époque, espèce, région).
#
# Sprint 3 : Analyse des facteurs comportementaux (régime, bipédie, technologie), visualisations avancées et synthèse des résultats.
#
# 3. Exécution des Sprints et Suivi Quotidien
#  Daily Stand-Up Meetings :
# Des stand-ups de 15 minutes ont été organisés chaque jour pour :
#
# Suivre l’avancement (ex. "J’ai nettoyé Time et standardisé les unités")
#
# Planifier les prochaines actions (ex. "Aujourd’hui j’analyse la relation Diet ↔ Cranial_Capacity")
#
# Identifier les blocages (ex. "Le format de certaines espèces n’est pas clair, à revoir ensemble")
#
# Adaptation et Réajustements :
# SCRUM a permis de :
#
# Réajuster rapidement les priorités (ex. suppression de certaines variables peu remplies)
#
# Replanifier des tâches en cas d’obstacle (ex. retarder le clustering au profit d’analyses plus descriptives)
#
# Réévaluer les hypothèses de travail à chaque sprint selon les données réellement exploitables
#
# 4. Révisions de Sprint et Rétrospective
# Évaluation des Incréments :
# À la fin de chaque sprint :
#
# Un notebook Python a été livré avec les traitements, les visualisations et les interprétations.
#
# Sprint 1 : exploration des distributions, gestion des données manquantes et des outliers.
#
# Sprint 2 : courbes temporelles, boxplots par espèce et zone.
#
# Sprint 3 : heatmaps de corrélation, analyse par Diet, biped, Tecno_type, et visualisation synthétique.
#
# 🔍 Sprint Review & Rétrospective :
# La review a permis de valider les livrables avec clarté (données prêtes, hypothèses évaluées, résultats lisibles).
#
# La rétrospective a mis en lumière des axes d'amélioration :
#
# automatiser davantage les conversions de formats
#
# anticiper les défis liés aux colonnes peu renseignées
#
# mieux documenter les hypothèses d’exclusion de certaines observations
#
#  5. Conclusion : Avantages de SCRUM dans Ce Projet
# L’approche SCRUM a apporté une structure claire et itérative à ce projet scientifique complexe. Elle a permis de :
#
# Diviser un objectif ambitieux en étapes concrètes, pilotées par la valeur analytique.
#
# Garantir un suivi régulier des actions grâce aux stand-ups.
#
# Livrer à chaque sprint des analyses validées, prêtes à être réutilisées ou enrichies.
#
# Faciliter la montée en qualité progressive des scripts, visualisations et interprétations.

# %% [markdown]
# ### 7. Livrables
#
# - **Artéfacts SCRUM:** Créez et soumettez les artéfacts SCRUM générés au cours du projet (backlogs, rapports de sprints, etc...).
# - **Utilisation de Github:** La restitution de ces livrables se fera par Github, en montant (push) vos modifications sur le dépôt qui vous a été attribué par e-mail.

# %% [markdown]
# _🧑🏻‍💻 Votre réponse ici_

# %% [markdown]
# Artéfacts SCRUM
# Product Backlog mis à jour
# Le product backlog a été construit sous forme de user stories et régulièrement mis à jour à chaque sprint.
# Il regroupe toutes les tâches du projet, classées par priorité et regroupées par sprint :
#
# Exploration et nettoyage des données (Sprint 1)
#
# Analyses temporelles, géographiques et morphologiques (Sprint 2)
#
# Corrélations comportementales, synthèse et visualisations finales (Sprint 3)
#
# Chaque tâche réalisée a été cochée, réévaluée ou ajustée en fonction des obstacles et découvertes durant l’analyse.
#
#  Graphiques et Analyses
# De nombreux artefacts analytiques et visuels ont été produits :
#
# Histogrammes et boxplots pour explorer les distributions (capacité crânienne, taille, etc.)
#
# Courbes d’évolution temporelle (Time vs Cranial_Capacity)
#
# Scatterplots, heatmaps de corrélation
#
# Visualisations comparatives par espèce, zone géographique ou régime alimentaire
#
# Ces visualisations ont servi à valider des hypothèses, détecter des tendances et orienter la réflexion scientifique à chaque sprint.
#
# Présentation Finale
# Une présentation synthétique a été préparée pour présenter :
#
# Le contexte et la problématique
#
# Les étapes de traitement (sprint par sprint)
#
# Les résultats analytiques clés
#
# Les recommandations ou interprétations biologiques possibles
#
# Elle a permis de communiquer les livrables de manière claire et didactique à des parties prenantes non techniques.
#
# Utilisation de GitHub
# Un dépôt GitHub a été utilisé tout au long du projet pour :
#
# Versionner les scripts Python (exploration, nettoyage, visualisation, modélisation)
#
# Archiver les rapports intermédiaires et les notebooks Jupyter
#
# Assurer la traçabilité des modifications, via des commits réguliers et des branches organisées par sprint
#
# Faciliter la collaboration (pull requests, commentaires de code, résolution de conflits)
#
# GitHub a servi de support centralisé pour l’ensemble du code source, assurant une collaboration fluide et une documentation continue du projet.

# %% [markdown]
# ## Conclusion
#
# Ce projet vise à offrir une expérience concrète de la gestion de projet agile appliquée à un cas réel en science des données.
# En travaillant sur un jeu de données paléoanthropologiques (Evolution_DataSets.csv), il permet de comprendre comment l’agilité – à travers les sprints, backlog, stand-ups, rétrospectives – contribue à la structuration, à la progression par itérations, et à la réussite d’un projet data.
# Au-delà de l’analyse technique, ce projet met en lumière l’importance de la collaboration, de l’adaptation continue, et de la priorisation des tâches pour atteindre des objectifs scientifiques complexes.
